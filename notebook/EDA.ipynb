# %%
import pandas as pd 

movie = pd.read_csv('../data/movies_metadata.csv')
rating = pd.read_csv('../data/ratings_small.csv')
link = pd.read_csv('../data/links_small.csv')
# Out:
# /var/folders/d1/6dwp1f5j4hv0wvtf0611w4br0000gn/T/ipykernel_70838/4226395533.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie = pd.read_csv('../data/movies_metadata.csv')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
movie.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
merged_1 = pd.merge(link, rating)

# %%
merged_1
# Out:
#         movieId   imdbId    tmdbId  userId  rating   timestamp
# 0             1   114709     862.0       7     3.0   851866703
# 1             1   114709     862.0       9     4.0   938629179
# 2             1   114709     862.0      13     5.0  1331380058
# 3             1   114709     862.0      15     2.0   997938310
# 4             1   114709     862.0      19     3.0   855190091
# ...         ...      ...       ...     ...     ...         ...
# 99999    161944   255313  159550.0     287     5.0  1470167824
# 100000   162376  4574334  410612.0      73     4.5  1474255532
# 100001   162542  5165344  392572.0     611     5.0  1471520667
# 100002   162672  3859980  402672.0     611     3.0  1471523986
# 100003   163949  2531318  391698.0     547     5.0  1476419239
#
# [100004 rows x 6 columns]

# %%
merged_1['imdb_id'] = 'tt' + merged_1['imdbId'].astype(int).astype(str).str.zfill(7)
df = pd.merge(merged_1, movie, on='imdb_id', how='inner')

# %%
df.head()
# Out:
#    movieId  imdbId  tmdbId  userId  rating   timestamp    imdb_id  adult  \
# 0        1  114709   862.0       7     3.0   851866703  tt0114709  False
# 1        1  114709   862.0       9     4.0   938629179  tt0114709  False
# 2        1  114709   862.0      13     5.0  1331380058  tt0114709  False
# 3        1  114709   862.0      15     2.0   997938310  tt0114709  False
# 4        1  114709   862.0      19     3.0   855190091  tt0114709  False
#
#                                belongs_to_collection    budget  ...  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  ...
# 1  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  ...
# 2  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  ...
# 3  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  ...
# 4  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  ...
#
#   release_date      revenue runtime                          spoken_languages  \
# ...

# %%
drop_cols = ['movieId','tmdbId','budget','homepage','revenue','tagline','spoken_languages','status', 'video','id','original_title','production_companies','production_countries','belongs_to_collection','imdbId','timestamp']

df1 = df.drop(columns=drop_cols, axis=1)

# %%
df.production_countries.value_counts()
# Out:
# production_countries
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]                                                                                                                   69890
# [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]                                                                    6311
# [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]                                                                                                                              2993
# [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]                                                                           2339
# [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]                                                                            1208
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99806 entries, 0 to 99805
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   userId             99806 non-null  int64
#  1   rating             99806 non-null  float64
#  2   timestamp          99806 non-null  int64
#  3   imdb_id            99806 non-null  object
#  4   adult              99806 non-null  object
#  5   genres             99806 non-null  object
#  6   original_language  99806 non-null  object
#  7   overview           99792 non-null  object
#  8   popularity         99806 non-null  object
#  9   poster_path        99800 non-null  object
#  10  release_date       99800 non-null  object
#  11  runtime            99806 non-null  float64
#  12  title              99806 non-null  object
#  13  vote_average       99806 non-null  float64
#  14  vote_count         99806 non-null  float64
# dtypes: float64(4), int64(2), object(9)
# ...

# %%
df1.head()
# Out:
#    userId  rating    imdb_id  adult  \
# 0       7     3.0  tt0114709  False
# 1       9     4.0  tt0114709  False
# 2      13     5.0  tt0114709  False
# 3      15     2.0  tt0114709  False
# 4      19     3.0  tt0114709  False
#
#                                               genres original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 2  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 3  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 4  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  Led by Woody, Andy's toys live happily in his ...  21.946943
# 2  Led by Woody, Andy's toys live happily in his ...  21.946943
# ...

# %%
df1['popularity'] = df1['popularity'].astype('float')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99806 entries, 0 to 99805
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   userId             99806 non-null  int64
#  1   rating             99806 non-null  float64
#  2   imdb_id            99806 non-null  object
#  3   adult              99806 non-null  object
#  4   genres             99806 non-null  object
#  5   original_language  99806 non-null  object
#  6   overview           99792 non-null  object
#  7   popularity         99806 non-null  float64
#  8   poster_path        99800 non-null  object
#  9   release_date       99800 non-null  object
#  10  runtime            99806 non-null  float64
#  11  title              99806 non-null  object
#  12  vote_average       99806 non-null  float64
#  13  vote_count         99806 non-null  float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 10.7+ MB

# %%
df1.to_parquet('../data/movie_data.parquet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df1.to_parquet('../data/movie_data.parquet')
#
# NameError: name 'df1' is not defined
